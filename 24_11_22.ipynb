# %% [markdown]
# <a href="https://colab.research.google.com/github/AshiTHOMAS/python-basic/blob/main/24_11_22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
supermarket=files.upload()
# Out:
#      <input type="file" id="files-f5ac8b36-c8ef-4639-b42f-5f0cd7a6b592" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f5ac8b36-c8ef-4639-b42f-5f0cd7a6b592">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
teams_and_leagues=files.upload()
# Out:
#      <input type="file" id="files-4dec2eb6-2ac0-451a-9861-5e2507ff8fcb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4dec2eb6-2ac0-451a-9861-5e2507ff8fcb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# %%
teamgoals={
    'teams':['England','Spain'],
    'goals':[2,4]
}
df= pd.DataFrame(teamgoals)
print(df)
# Out:
#      teams  goals
# 0  England      2
# 1    Spain      4

# %%
players={
    'name':['James','Pedri'],
    'nationaity':['Columbia','Spain']
}
x= pd.DataFrame(players)
print(x)
# Out:
#     name nationaity
# 0  James   Columbia
# 1  Pedri      Spain

# %%
marks=[10,20,30,40]
y=pd.DataFrame(marks)
print(y)
# Out:
#     0
# 0  10
# 1  20
# 2  30
# 3  40

# %%
import pandas as pd
z=pd.read_csv("Supermarket_sales.csv")
print(z)
# Out:
#        No    InvoiceID Branch       City Customertype  Gender  \
# 0       1  750-67-8428      A     Yangon       Member  Female
# 1       2  226-31-3081      C  Naypyitaw       Normal  Female
# 2       3  631-41-3108      A     Yangon       Normal    Male
# 3       4  123-19-1176      A     Yangon       Member    Male
# 4       5  373-73-7910      A     Yangon       Normal    Male
# ..    ...          ...    ...        ...          ...     ...
# 995   996  233-67-5758      C  Naypyitaw       Normal    Male
# 996   997  303-96-2227      B   Mandalay       Normal  Female
# 997   998  727-02-1313      A     Yangon       Member    Male
# 998   999  347-56-2442      A     Yangon       Normal    Male
# 999  1000  849-09-3807      A     Yangon       Member  Female
#
#                 Productline  Unitprice  Quantity      Tax      Total  \
# 0         Health and beauty      74.69         7  26.1415   548.9715
# 1    Electronic accessories      15.28         5   3.8200    80.2200
# ...

# %%
import pandas as pd
z=pd.read_csv("Supermarket_sales.csv")
print(z.head(4))
# Out:
#    No    InvoiceID Branch       City Customertype  Gender  \
# 0   1  750-67-8428      A     Yangon       Member  Female
# 1   2  226-31-3081      C  Naypyitaw       Normal  Female
# 2   3  631-41-3108      A     Yangon       Normal    Male
# 3   4  123-19-1176      A     Yangon       Member    Male
#
#               Productline  Unitprice  Quantity      Tax     Total       Date  \
# 0       Health and beauty      74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories      15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle      46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty      58.22         8  23.2880  489.0480  1/27/2019
#
#     Time      Payment    cogs  gross_margin_percentage  gross_iincome  Rating
# 0  13:08      Ewallet  522.83                 4.761905        26.1415     9.1
# 1  10:29         Cash   76.40                 4.761905         3.8200     9.6
# ...

# %%
import pandas as pd
z=pd.read_csv("Supermarket_sales.csv")
print(z.tail(3))
# Out:
#        No    InvoiceID Branch    City Customertype  Gender  \
# 997   998  727-02-1313      A  Yangon       Member    Male
# 998   999  347-56-2442      A  Yangon       Normal    Male
# 999  1000  849-09-3807      A  Yangon       Member  Female
#
#              Productline  Unitprice  Quantity     Tax    Total       Date  \
# 997   Food and beverages      31.84         1   1.592   33.432   2/9/2019
# 998   Home and lifestyle      65.82         1   3.291   69.111  2/22/2019
# 999  Fashion accessories      88.34         7  30.919  649.299  2/18/2019
#
#       Time Payment    cogs  gross_margin_percentage  gross_iincome  Rating
# 997  13:22    Cash   31.84                 4.761905          1.592     7.7
# 998  15:33    Cash   65.82                 4.761905          3.291     4.1
# 999  13:28    Cash  618.38                 4.761905         30.919     6.6

# %%
z['City']
# Out:
# 0         Yangon
# 1      Naypyitaw
# 2         Yangon
# 3         Yangon
# 4         Yangon
#          ...
# 995    Naypyitaw
# 996     Mandalay
# 997       Yangon
# 998       Yangon
# 999       Yangon
# Name: City, Length: 1000, dtype: object

# %%
z['Branch'],z['City']
# Out:
# (0      A
#  1      C
#  2      A
#  3      A
#  4      A
#        ..
#  995    C
#  996    B
#  997    A
#  998    A
#  999    A
#  Name: Branch, Length: 1000, dtype: object, 0         Yangon
#  1      Naypyitaw
#  2         Yangon
#  3         Yangon
#  4         Yangon
#           ...
#  995    Naypyitaw
#  996     Mandalay
#  997       Yangon
#  998       Yangon
#  999       Yangon
#  Name: City, Length: 1000, dtype: object)

# %%
for i in z.index:
  print(z.City[i],z.Branch[i])
# Out:
# Yangon A
# Naypyitaw C
# Yangon A
# Yangon A
# Yangon A
# Naypyitaw C
# Yangon A
# Naypyitaw C
# Yangon A
# Mandalay B
# Mandalay B
# Mandalay B
# Yangon A
# Yangon A
# Yangon A
# Mandalay B
# Yangon A
# Yangon A
# Yangon A
# Mandalay B
# Naypyitaw C
# Mandalay B
# Mandalay B
# Yangon A
# Yangon A
# Yangon A
# Mandalay B
# Yangon A
# Mandalay B
# Yangon A
# Mandalay B
# Mandalay B
# Mandalay B
# Yangon A
# Naypyitaw C
# Naypyitaw C
# Yangon A
# Yangon A
# Naypyitaw C
# Mandalay B
# Mandalay B
# Naypyitaw C
# Mandalay B
# Naypyitaw C
# Naypyitaw C
# Mandalay B
# Mandalay B
# Mandalay B
# Mandalay B
# Naypyitaw C
# Naypyitaw C
# Yangon A
# Mandalay B
# Naypyitaw C
# Mandalay B
# Naypyitaw C
# Yangon A
# Yangon A
# Yangon A
# Naypyitaw C
# Naypyitaw C
# Naypyitaw C
# Mandalay B
# Yangon A
# Mandalay B
# Yangon A
# Naypyitaw C
# Mandalay B
# Yangon A
# Yangon A
# Naypyitaw C
# Naypyitaw C
# Mandalay B
# Naypyitaw C
# Yangon A
# Naypyitaw C
# Naypyitaw C
# Yangon A
# Naypyitaw C
# ...

# %%
from google.colab import files
pleyers=files.upload()
# Out:
#      <input type="file" id="files-3a16e034-b7a7-4782-9566-b911eccf0cae" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3a16e034-b7a7-4782-9566-b911eccf0cae">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
a=pd.read_csv('players_20.csv')

# %%
print(a.short_name.head(1))
a.overall.max()
# Out:
# 0    L. Messi
# Name: short_name, dtype: object
# 94

# %%
a.age.min()
# Out:
# 16

# %%
a.age.max()
# Out:
# 42

# %%
a.overall.idxmax()
# Out:
# 0

# %%
pcount=a.sofifa_id.count()
print(pcount)
# Out:
# 18278

# %%
a.age.mean()
# Out:
# 25.283291388554545

# %%
for i in a.index:
  if a.club[i] == 'FC Barcelona':
    print(a.short_name[i])
# Out:
# L. Messi
# M. ter Stegen
# L. Suárez
# Sergio Busquets
# A. Griezmann
# Piqué
# Jordi Alba
# S. Umtiti
# I. Rakitić
# F. de Jong
# C. Lenglet
# Neto
# O. Dembélé
# Arthur
# A. Vidal
# Nélson Semedo
# Sergi Roberto
# Rafinha
# Junior Firpo
# Aleñá
# Riqui Puig
# J. Todibo
# M. Wagué
# H. Abe
# L. Reis
# Abel Ruiz
# Oriol Busquets
# Carles Pérez
# Miranda
# Chumi
# Álex Collado
# Jorge Cuenca
# Iñaki Peña
